# %%
import pandas as pd

# %%
df = pd.read_csv('data_sets/INM_estatal_jul25.csv')
df.head()
# Out:
#    anio  clave_ent         entidad bien_juridico_afectado         tipo_delito  \
# 0  2015          1  Aguascalientes          El patrimonio  Abuso de confianza
# 1  2015          1  Aguascalientes          El patrimonio  Abuso de confianza
# 2  2015          1  Aguascalientes          El patrimonio  Abuso de confianza
# 3  2015          1  Aguascalientes          El patrimonio  Abuso de confianza
# 4  2015          1  Aguascalientes          El patrimonio  Abuso de confianza
#
#        subtipo_delito           modalidad        mes       fecha  \
# 0  Abuso de confianza  Abuso de confianza      Abril  01/04/2015
# 1  Abuso de confianza  Abuso de confianza     Agosto  01/08/2015
# 2  Abuso de confianza  Abuso de confianza  Diciembre  01/12/2015
# 3  Abuso de confianza  Abuso de confianza      Enero  01/01/2015
# 4  Abuso de confianza  Abuso de confianza    Febrero  01/02/2015
#
#    incidencia_delictiva entidad_federativa
# 0                    22     Aguascalientes
# ...

# %%
data = pd.read_csv('data_sets/data.csv', )
data.head()
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  5
# 3  4  4
# 4  5  5

# %%
x=data[['x']]
x
# Out:
#    x
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
y=data[['y']]
y
# Out:
#    y
# 0  2
# 1  4
# 2  5
# 3  4
# 4  5

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x,y)
predictions = model.score(x,y)
predictions
# Out:
# 0.6000000000000001

# %%
# grafica los datos y la prediccion
import matplotlib.pyplot as plt
plt.scatter(x, y, color='blue', label='Datos reales')
plt.plot(x, model.predict(x), color='red', label='Predicción del modelo')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresión Lineal')
plt.legend()
plt.show()
